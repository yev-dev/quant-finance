# %%
import pandas as pd

# %%
df = pd.read_excel("https://github.com/chris1610/pbpython/blob/master/data/sample-salesv3.xlsx?raw=True")
df["date"] = pd.to_datetime(df['date'])
df.head()
# Out:
#    account number                         name       sku  quantity  \
# 0          740150                   Barton LLC  B1-20000        39
# 1          714466              Trantow-Barrows  S2-77896        -1
# 2          218895                    Kulas Inc  B1-69924        23
# 3          307599  Kassulke, Ondricka and Metz  S1-65481        41
# 4          412290                Jerde-Hilpert  S2-34077         6
#
#    unit price  ext price                date
# 0       86.69    3380.91 2014-01-01 07:21:51
# 1       63.16     -63.16 2014-01-01 10:00:47
# 2       90.70    2086.10 2014-01-01 13:24:58
# 3       21.05     863.05 2014-01-01 15:05:22
# 4       83.21     499.26 2014-01-01 23:26:55

# %%
df.set_index('date').resample('M')["ext price"].sum()
# Out:
# /var/folders/zn/8l1qxk_s2z12z2dtb7lgbsdm0000gn/T/ipykernel_5020/3005269738.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.set_index('date').resample('M')["ext price"].sum()
# date
# 2014-01-31    185361.66
# 2014-02-28    146211.62
# 2014-03-31    203921.38
# 2014-04-30    174574.11
# 2014-05-31    165418.55
# 2014-06-30    174089.33
# 2014-07-31    191662.11
# 2014-08-31    153778.59
# 2014-09-30    168443.17
# 2014-10-31    171495.32
# 2014-11-30    119961.22
# 2014-12-31    163867.26
# Freq: ME, Name: ext price, dtype: float64

# %%
df.set_index('date').groupby('name')["ext price"].resample("M").sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.set_index('date').groupby('name')["ext price"].resample("M").sum()
#
# NameError: name 'df' is not defined

# %%
# Improves agg() function
df.set_index('date').groupby('name')["ext price"].resample("M").sum().unstack().fillna(0)
# Out:
# /var/folders/zn/8l1qxk_s2z12z2dtb7lgbsdm0000gn/T/ipykernel_5020/493666191.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.set_index('date').groupby('name')["ext price"].resample("M").sum().unstack().fillna(0)
# date                             2014-01-31  2014-02-28  2014-03-31  \
# name
# Barton LLC                          6177.57    12218.03     3513.53
# Cronin, Oberbrunner and Spencer     1141.75    13976.26    11691.62
# Frami, Hills and Schmidt            5112.34     4124.53    10397.44
# Fritsch, Russel and Anderson       15130.77     9595.35     5153.80
# Halvorson, Crona and Champlin       9997.17     7082.15     9610.91
# Herman LLC                         10749.84     5831.40     6359.58
# Jerde-Hilpert                      11274.33     4088.40    15254.78
# Kassulke, Ondricka and Metz         7322.83     3061.12    10159.76
# Keeling LLC                         6847.86     3383.45    17110.10
# ...

# %%
df.agg({'ext price': ['sum', 'mean'], 'quantity': ['sum', 'mean'], 'unit price': ['mean']})
# Out:
#          ext price      quantity  unit price
# sum   2.018784e+06  36463.000000         NaN
# mean  1.345856e+03     24.308667   55.007527

# %%
# Custom aggregation function with a name
get_max = lambda x: x.value_counts(dropna=False).index[0]
get_max.__name__ = "most frequent"

# %%
import collections
f = collections.OrderedDict([('ext price', ['sum', 'mean']), ('quantity', ['sum', 'mean']), ('sku', [get_max])])
df.agg(f)
# Out:
#                   ext price      quantity       sku
# sum            2.018784e+06  36463.000000       NaN
# mean           1.345856e+03     24.308667       NaN
# most frequent           NaN           NaN  S2-77896

# %%
https://pbpython.com/market-basket-analysis.html
